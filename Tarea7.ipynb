# %% [markdown]
# <a href="https://colab.research.google.com/github/pepinadas/cyp_2021/blob/main/Tarea7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Problema 4.11
#No compila y no se por que! :c
print("Colocar el total de paises de Sur, Centro y Norteamérica")

Tps = int(input("Paises de sudamerica: "))
Tpc = int(input("Paises de centroamerica: "))
Tpn = int(input("Paises de norteamérica: "))
Sur = [0 for I in range(Tps)]
Centro = [0 for I in range(Tpc)]
Norte = [0 for I in range(Tpn)]
America = [0 for I in range(90)]

if (1 <= Tps <= 30) and (1 <= Tpc <= 30) and (1 <= Tpn <= 30):
  
  print("Ingrese los nombres de los paises de Sudamérica")
  I = 1
  for I in range (Tps):
    Sur[I] = str(input(f"Ingrese nombre del pais {I+1}: "))
    I = I + 1

  print("Ingrese los nombres de los países de Centroamérica")
  I = 1                                                       #Parte A
  for I in range (Tpc):
    Centro[I] = str(input(f"Ingrese nombre del pais {I+1}: "))
    I = I + 1
  
  print("Ingrese los nombres de los países de Norteamérica")
  I = 1
  for I in range (Tpn):
    Norte[I] = str(input(f"Ingrese nombre del pais {I+1}: "))
    I = I + 1
  Ps = 1                                                      #Parte B
  Pc = 1
  Pn = 1
  Pa = 1
  while Ps <= Tps and Pc <= Tpc and Pn <= Tpn:
    Pa = Pa + 1

    if (Sur[Ps] < Centro[Pc]) and (Sur[Ps] < Norte[Pn]):
      America[Pa] = Sur[Ps]
      Ps = Ps + 1
    else:
      if (Centro[Pc]<Norte[Pn]):
        America[Pa] = Centro[Pc]
        Pc = Pc + 1
      else:
        America[Pa] = Norte[Pn]
        Pn = Pn + 1
  while Ps <= Tps and Pc <= Tpc:
    Pa = Pa + 1
    if Sur[Ps]<Centro[Pc]:
      America[Pa] = Sur[Ps]
      Ps = Ps + 1
    else:
      America[Pa] = Centro[Pc]
      Pc = Pc + 1
  while Ps <= Tps and Pn <= Tpn:                               #Parte C
    Pa = Pa + 1
    if Sur[Ps]<Norte[Pn]:
      America[Pa] = Sur[Ps]
      Ps = Ps + 1
    else:
      America[Pa] = Norte[Pn]
      Pn = Pn + 1
  while Pc <= Tpc and Pn <= Tpn:
    Pa = Pa + 1
    if Centro[Pc]<Norte[Pn]:
      America[Pa] = Centro[Pc]
      Pc = Pc + 1
    else:
      America[Pa] = Norte[Pn]
      Pn = Pn +1
  while Ps <= Tps:                                           #Parte D
    Pa = Pa + 1
    America[Pa] = Sur[Ps]
    Ps = Ps + 1
  while Pc<=Tpc:
    Pa = Pa + 1
    America[Pa] = Centro[Pc]
    Pc = Pc + 1
  while Pn <= Tpn:
    Pa = Pa + 1
    America[Pa] = Norte[Pn]
    Pn = Pn + 1
  print("Arreglo América")
  I = 1                                                      #Parte E
  for I in range (Pa):
    print(America[I])
    I = I + 1

else:
  print("Verifique el número de países ingresados")
